# %% [markdown]
# **<center><h1>HOUM</h1></center>**
# <center>Jonathan Domínguez Aldana</center>
#
# <br></br>
#
# **Introducción:**
#
# Houm es una startup que permite administrar, arrendar y vender propiedades rápido, seguro y fácil a miles de usuarios en Latinoamérica. En su desafío por entregar la mejor experiencia de usuarios, la empresa y su head de operaciones le pide hacer un estudio sobre el comportamiento de sus visitas en torno al clima. Es por esto que lo contactan a usted para dar respuestas a las preguntas de la compañía.
#
# Carlos, nuestro data scientist, le informa que existen tres fuentes de información relevantes, las cuales contienen información de la operación que podrían ser de utilidad. Los tres archivos se detallan a continuación (presentes en el archivo dataset.zip adjunto):
#
# <ul>
#   <li><b>properties.csv: </b> Contiene información básica de las características de la propiedad y su información geográfica. Las columnas de este archivo son las siguientes: property_id, business_type, type, bedrooms, bathrooms, latitude, longitude, locality, city & country.</li>
#   <li><b>users.csv: </b> Contiene la información de los propietarios y su relación con la propiedad. Las columnas de este archivo son las siguientes: property_id, user_id, name, last_name & country.</li>
#   <li><b>visits.csv:</b> Contiene la información de los clientes que se han registrado en alguna visita a una propiedad. Las columnas de este archivo son las siguientes: schedule_id, property_id, begin_date, end_date, type_visit & status.</li>
# </ul>
#
# Por otro lado, Carlos le comenta que existe un servicio para obtener información de las condiciones climáticas de cada país. Se puede consultar este servicio por medio de su API, la cual esta documentada aquí. Se puede consultar la temperatura y clima de una localidad mediante la siguiente consulta.
#
# <br></br>
#
# **Ejemplo de Request API Wheather VisualCrossing:**
#
# ﻿ https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{lat},{lng}/{start_date}/{end_date}?key={API_KEY}&include=days
#
# <br></br>
#
# **Posibles condiciones climáticas retornada por la API:**
#
# https://github.com/visualcrossing/WeatherApi/blob/master/lang/en.txt
#
# **Nota:** Para la utilización de la api se debe proveer el siguiente API KEY. Esta tiene un límite de 1.000 registros al día. Debes registrarte en https://www.visualcrossing.com/sign-up para obtener la KEY.
#
# <br></br>
#
# **Preguntas del desafío:**
#
# <ul>
# <li>¿Cuántas visitas se realizaron en total?</li>
# <li>¿Cuál es el promedio de propiedades por usuario?</li>
# <li>¿Cuál era la temperatura promedio de todas las visitas que realizó el usuario con ID 2?</li>
# <li>¿Cuál es la temperatura promedio de las visitas para los días con lluvia?</li>
# <li>¿Cuál es la temperatura promedio para las visitas realizadas en la localidad de Suba?</li>
# </ul>

# %% [markdown]
# **<h1>Importando Librerías</h1>**
#
# Todas las librerías que serán requeridas para la solución de esta prueba técnica se enlistan a continuación:

# %%
import numpy as np
import pandas as pd
import requests
from tqdm import tqdm

# %% [markdown]
# **<h1>1. Extracción y Eploración de Datos:</h1>**
#
# **<h3>1.1 Condiciones climáticas por API:</h3>**
#
# Comenzaremos por realizar la conexión a la API. Para eso usaremos la librería de requests de Python. Vamos a realizar un ejercicio sencillo estableciendo datos de ubicación y de fechas como prueba.

# %%
# Me gustaría ver datos de mi ciudad: Querétaro, México. 
lat = 20.835996656
lng = -99.85082993

# Podemos observar de la documentación de la API 
# que el formato de fecha es el universal: YYYY-MM-DD
# https://www.visualcrossing.com/resources/blog/how-to-load-historical-weather-data-using-python-without-scraping/
start_date = '2022-03-01'
end_date = '2022-03-31'

# No es la mejor manera de almacenar una llave privada
# sería mejor usar variables de entorno.
with open('api_key.txt', 'r') as f:
  API_KEY = f.readlines()[0]

# Let us look at the data from March
response = requests.get(f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{lat},{lng}/{start_date}/{end_date}?key={API_KEY}&include=days")
print(response)
json_response = response.json()
json_response
# Out:
# <Response [200]>
# {'address': '20.835996656,-99.85082993',
#  'days': [{'cloudcover': 0.0,
#    'conditions': 'Clear',
#    'datetime': '2022-03-01',
#    'datetimeEpoch': 1646114400,
#    'description': 'Clear conditions throughout the day.',
#    'dew': 32.6,
#    'feelslike': 59.0,
#    'feelslikemax': 78.9,
#    'feelslikemin': 34.9,
#    'humidity': 46.7,
#    'icon': 'clear-day',
#    'moonphase': 1.0,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1020.6,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 19.7,
#    'solarradiation': 274.6,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:59:32',
#    'sunriseEpoch': 1646139572,
#    'sunset': '18:44:08',
#    'sunsetEpoch': 1646181848,
#    'temp': 59.7,
#    'tempmax': 80.7,
#    'tempmin': 37.3,
#    'uvindex': 10.0,
#    'visibility': 10.8,
#    'winddir': 100.1,
#    'windgust': 10.1,
#    'windspeed': 18.3},
#   {'cloudcover': 3.3,
#    'conditions': 'Clear',
#    'datetime': '2022-03-02',
#    'datetimeEpoch': 1646200800,
#    'description': 'Clear conditions throughout the day.',
#    'dew': 34.0,
#    'feelslike': 59.9,
#    'feelslikemax': 80.0,
#    'feelslikemin': 37.2,
#    'humidity': 44.4,
#    'icon': 'clear-day',
#    'moonphase': 1.0,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1019.8,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 19.8,
#    'solarradiation': 276.0,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:58:45',
#    'sunriseEpoch': 1646225925,
#    'sunset': '18:44:32',
#    'sunsetEpoch': 1646268272,
#    'temp': 60.3,
#    'tempmax': 82.5,
#    'tempmin': 41.1,
#    'uvindex': 10.0,
#    'visibility': 11.0,
#    'winddir': 120.6,
#    'windgust': 10.5,
#    'windspeed': 18.3},
#   {'cloudcover': 7.5,
#    'conditions': 'Clear',
#    'datetime': '2022-03-03',
#    'datetimeEpoch': 1646287200,
#    'description': 'Clear conditions throughout the day.',
#    'dew': 40.2,
#    'feelslike': 58.8,
#    'feelslikemax': 76.4,
#    'feelslikemin': 39.1,
#    'humidity': 57.9,
#    'icon': 'clear-day',
#    'moonphase': 0.0,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1018.6,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 19.7,
#    'solarradiation': 274.5,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:57:57',
#    'sunriseEpoch': 1646312277,
#    'sunset': '18:44:54',
#    'sunsetEpoch': 1646354694,
#    'temp': 58.8,
#    'tempmax': 76.4,
#    'tempmin': 39.1,
#    'uvindex': 10.0,
#    'visibility': 11.5,
#    'winddir': 78.2,
#    'windgust': 11.6,
#    'windspeed': 15.4},
#   {'cloudcover': 13.9,
#    'conditions': 'Clear',
#    'datetime': '2022-03-04',
#    'datetimeEpoch': 1646373600,
#    'description': 'Clear conditions throughout the day.',
#    'dew': 42.3,
#    'feelslike': 60.4,
#    'feelslikemax': 78.0,
#    'feelslikemin': 42.9,
#    'humidity': 58.3,
#    'icon': 'clear-day',
#    'moonphase': 0.02,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1018.1,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 19.6,
#    'solarradiation': 274.7,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:57:08',
#    'sunriseEpoch': 1646398628,
#    'sunset': '18:45:17',
#    'sunsetEpoch': 1646441117,
#    'temp': 60.6,
#    'tempmax': 78.0,
#    'tempmin': 42.9,
#    'uvindex': 10.0,
#    'visibility': 11.6,
#    'winddir': 96.9,
#    'windgust': 13.0,
#    'windspeed': 19.7},
#   {'cloudcover': 19.7,
#    'conditions': 'Clear',
#    'datetime': '2022-03-05',
#    'datetimeEpoch': 1646460000,
#    'description': 'Clear conditions throughout the day.',
#    'dew': 41.1,
#    'feelslike': 65.1,
#    'feelslikemax': 79.2,
#    'feelslikemin': 48.3,
#    'humidity': 45.7,
#    'icon': 'clear-day',
#    'moonphase': 0.04,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1017.5,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 19.0,
#    'solarradiation': 265.3,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:56:19',
#    'sunriseEpoch': 1646484979,
#    'sunset': '18:45:39',
#    'sunsetEpoch': 1646527539,
#    'temp': 65.3,
#    'tempmax': 80.7,
#    'tempmin': 48.3,
#    'uvindex': 10.0,
#    'visibility': 11.0,
#    'winddir': 166.5,
#    'windgust': 9.6,
#    'windspeed': 13.9},
#   {'cloudcover': 10.7,
#    'conditions': 'Clear',
#    'datetime': '2022-03-06',
#    'datetimeEpoch': 1646546400,
#    'description': 'Clear conditions throughout the day.',
#    'dew': 34.8,
#    'feelslike': 65.4,
#    'feelslikemax': 79.4,
#    'feelslikemin': 46.4,
#    'humidity': 35.3,
#    'icon': 'clear-day',
#    'moonphase': 0.08,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1015.5,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 19.7,
#    'solarradiation': 275.5,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:55:30',
#    'sunriseEpoch': 1646571330,
#    'sunset': '18:46:00',
#    'sunsetEpoch': 1646613960,
#    'temp': 65.7,
#    'tempmax': 80.9,
#    'tempmin': 46.5,
#    'uvindex': 10.0,
#    'visibility': 10.8,
#    'winddir': 239.4,
#    'windgust': 7.4,
#    'windspeed': 13.9},
#   {'cloudcover': 32.9,
#    'conditions': 'Partially cloudy',
#    'datetime': '2022-03-07',
#    'datetimeEpoch': 1646632800,
#    'description': 'Partly cloudy throughout the day.',
#    'dew': 38.3,
#    'feelslike': 66.5,
#    'feelslikemax': 80.1,
#    'feelslikemin': 50.1,
#    'humidity': 38.3,
#    'icon': 'partly-cloudy-day',
#    'moonphase': 0.12,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1014.2,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 24.3,
#    'solarradiation': 293.1,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:54:40',
#    'sunriseEpoch': 1646657680,
#    'sunset': '18:46:22',
#    'sunsetEpoch': 1646700382,
#    'temp': 66.6,
#    'tempmax': 82.5,
#    'tempmin': 50.1,
#    'uvindex': 10.0,
#    'visibility': 10.2,
#    'winddir': 184.2,
#    'windgust': 16.3,
#    'windspeed': 19.7},
#   {'cloudcover': 35.0,
#    'conditions': 'Partially cloudy',
#    'datetime': '2022-03-08',
#    'datetimeEpoch': 1646719200,
#    'description': 'Partly cloudy throughout the day.',
#    'dew': 42.7,
#    'feelslike': 65.2,
#    'feelslikemax': 79.9,
#    'feelslikemin': 46.5,
#    'humidity': 53.8,
#    'icon': 'partly-cloudy-day',
#    'moonphase': 0.16,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1013.1,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 24.1,
#    'solarradiation': 280.4,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:53:49',
#    'sunriseEpoch': 1646744029,
#    'sunset': '18:46:43',
#    'sunsetEpoch': 1646786803,
#    'temp': 65.5,
#    'tempmax': 82.3,
#    'tempmin': 46.5,
#    'uvindex': 10.0,
#    'visibility': 10.0,
#    'winddir': 191.5,
#    'windgust': 28.9,
#    'windspeed': 17.2},
#   {'cloudcover': 20.6,
#    'conditions': 'Partially cloudy',
#    'datetime': '2022-03-09',
#    'datetimeEpoch': 1646805600,
#    'description': 'Partly cloudy throughout the day.',
#    'dew': 29.7,
#    'feelslike': 65.4,
#    'feelslikemax': 80.0,
#    'feelslikemin': 42.2,
#    'humidity': 28.2,
#    'icon': 'partly-cloudy-day',
#    'moonphase': 0.21,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1011.8,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 24.4,
#    'solarradiation': 282.6,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:52:58',
#    'sunriseEpoch': 1646830378,
#    'sunset': '18:47:03',
#    'sunsetEpoch': 1646873223,
#    'temp': 65.9,
#    'tempmax': 82.5,
#    'tempmin': 44.7,
#    'uvindex': 10.0,
#    'visibility': 10.7,
#    'winddir': 261.2,
#    'windgust': 23.5,
#    'windspeed': 28.9},
#   {'cloudcover': 23.7,
#    'conditions': 'Partially cloudy',
#    'datetime': '2022-03-10',
#    'datetimeEpoch': 1646892000,
#    'description': 'Becoming cloudy in the afternoon.',
#    'dew': 24.4,
#    'feelslike': 64.9,
#    'feelslikemax': 80.0,
#    'feelslikemin': 44.7,
#    'humidity': 25.2,
#    'icon': 'partly-cloudy-day',
#    'moonphase': 0.25,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1011.9,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 24.8,
#    'solarradiation': 286.9,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:52:07',
#    'sunriseEpoch': 1646916727,
#    'sunset': '18:47:24',
#    'sunsetEpoch': 1646959644,
#    'temp': 65.1,
#    'tempmax': 80.7,
#    'tempmin': 44.7,
#    'uvindex': 10.0,
#    'visibility': 12.4,
#    'winddir': 242.0,
#    'windgust': 18.8,
#    'windspeed': 20.8},
#   {'cloudcover': 0.3,
#    'conditions': 'Clear',
#    'datetime': '2022-03-11',
#    'datetimeEpoch': 1646978400,
#    'description': 'Clear conditions throughout the day.',
#    'dew': 20.8,
#    'feelslike': 64.6,
#    'feelslikemax': 79.5,
#    'feelslikemin': 50.1,
#    'humidity': 20.7,
#    'icon': 'clear-day',
#    'moonphase': 0.3,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1013.0,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 25.7,
#    'solarradiation': 297.6,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:51:15',
#    'sunriseEpoch': 1647003075,
#    'sunset': '18:47:44',
#    'sunsetEpoch': 1647046064,
#    'temp': 64.9,
#    'tempmax': 81.9,
#    'tempmin': 50.1,
#    'uvindex': 10.0,
#    'visibility': 13.0,
#    'winddir': 253.9,
#    'windgust': 15.4,
#    'windspeed': 23.0},
#   {'cloudcover': 22.1,
#    'conditions': 'Partially cloudy',
#    'datetime': '2022-03-12',
#    'datetimeEpoch': 1647064800,
#    'description': 'Partly cloudy throughout the day.',
#    'dew': 36.4,
#    'feelslike': 48.5,
#    'feelslikemax': 62.5,
#    'feelslikemin': 35.7,
#    'humidity': 62.3,
#    'icon': 'partly-cloudy-day',
#    'moonphase': 0.35,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': ['rain'],
#    'pressure': 1023.2,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 12.8,
#    'solarradiation': 149.0,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:50:23',
#    'sunriseEpoch': 1647089423,
#    'sunset': '18:48:04',
#    'sunsetEpoch': 1647132484,
#    'temp': 50.4,
#    'tempmax': 62.5,
#    'tempmin': 39.5,
#    'uvindex': 6.0,
#    'visibility': 10.4,
#    'winddir': 72.5,
#    'windgust': 8.5,
#    'windspeed': 25.3},
#   {'cloudcover': 1.1,
#    'conditions': 'Clear',
#    'datetime': '2022-03-13',
#    'datetimeEpoch': 1647151200,
#    'description': 'Clear conditions throughout the day.',
#    'dew': 34.2,
#    'feelslike': 56.5,
#    'feelslikemax': 78.7,
#    'feelslikemin': 33.7,
#    'humidity': 47.3,
#    'icon': 'clear-day',
#    'moonphase': 0.39,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1020.3,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 25.2,
#    'solarradiation': 292.2,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:49:31',
#    'sunriseEpoch': 1647175771,
#    'sunset': '18:48:23',
#    'sunsetEpoch': 1647218903,
#    'temp': 57.7,
#    'tempmax': 78.7,
#    'tempmin': 37.5,
#    'uvindex': 10.0,
#    'visibility': 11.3,
#    'winddir': 142.9,
#    'windgust': 10.1,
#    'windspeed': 20.8},
#   {'cloudcover': 10.1,
#    'conditions': 'Clear',
#    'datetime': '2022-03-14',
#    'datetimeEpoch': 1647237600,
#    'description': 'Clear conditions throughout the day.',
#    'dew': 36.1,
#    'feelslike': 65.0,
#    'feelslikemax': 80.2,
#    'feelslikemin': 51.5,
#    'humidity': 37.8,
#    'icon': 'clear-day',
#    'moonphase': 0.43,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1016.1,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 25.2,
#    'solarradiation': 292.9,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:48:38',
#    'sunriseEpoch': 1647262118,
#    'sunset': '18:48:43',
#    'sunsetEpoch': 1647305323,
#    'temp': 65.4,
#    'tempmax': 82.5,
#    'tempmin': 51.5,
#    'uvindex': 10.0,
#    'visibility': 11.2,
#    'winddir': 222.3,
#    'windgust': 14.1,
#    'windspeed': 18.3},
#   {'cloudcover': 10.1,
#    'conditions': 'Clear',
#    'datetime': '2022-03-15',
#    'datetimeEpoch': 1647324000,
#    'description': 'Clear conditions throughout the day.',
#    'dew': 40.8,
#    'feelslike': 60.7,
#    'feelslikemax': 73.5,
#    'feelslikemin': 44.7,
#    'humidity': 50.1,
#    'icon': 'clear-day',
#    'moonphase': 0.46,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1019.8,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 25.0,
#    'solarradiation': 289.2,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:47:45',
#    'sunriseEpoch': 1647348465,
#    'sunset': '18:49:02',
#    'sunsetEpoch': 1647391742,
#    'temp': 60.7,
#    'tempmax': 73.5,
#    'tempmin': 44.7,
#    'uvindex': 10.0,
#    'visibility': 10.6,
#    'winddir': 69.2,
#    'windgust': 10.5,
#    'windspeed': 19.7},
#   {'cloudcover': 44.1,
#    'conditions': 'Partially cloudy',
#    'datetime': '2022-03-16',
#    'datetimeEpoch': 1647410400,
#    'description': 'Partly cloudy throughout the day.',
#    'dew': 41.7,
#    'feelslike': 62.4,
#    'feelslikemax': 77.4,
#    'feelslikemin': 43.6,
#    'humidity': 49.9,
#    'icon': 'partly-cloudy-day',
#    'moonphase': 0.48,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1017.3,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 20.9,
#    'solarradiation': 243.6,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:46:52',
#    'sunriseEpoch': 1647434812,
#    'sunset': '18:49:21',
#    'sunsetEpoch': 1647478161,
#    'temp': 62.8,
#    'tempmax': 77.4,
#    'tempmin': 46.5,
#    'uvindex': 10.0,
#    'visibility': 9.9,
#    'winddir': 129.2,
#    'windgust': 12.3,
#    'windspeed': 17.2},
#   {'cloudcover': 40.8,
#    'conditions': 'Partially cloudy',
#    'datetime': '2022-03-17',
#    'datetimeEpoch': 1647496800,
#    'description': 'Becoming cloudy in the afternoon.',
#    'dew': 38.4,
#    'feelslike': 66.4,
#    'feelslikemax': 79.3,
#    'feelslikemin': 51.9,
#    'humidity': 39.6,
#    'icon': 'partly-cloudy-day',
#    'moonphase': 0.5,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1012.1,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 25.6,
#    'solarradiation': 296.7,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:45:59',
#    'sunriseEpoch': 1647521159,
#    'sunset': '18:49:40',
#    'sunsetEpoch': 1647564580,
#    'temp': 66.7,
#    'tempmax': 81.6,
#    'tempmin': 51.9,
#    'uvindex': 10.0,
#    'visibility': 9.8,
#    'winddir': 262.7,
#    'windgust': 20.4,
#    'windspeed': 20.8},
#   {'cloudcover': 5.5,
#    'conditions': 'Clear',
#    'datetime': '2022-03-18',
#    'datetimeEpoch': 1647583200,
#    'description': 'Clear conditions throughout the day.',
#    'dew': 36.4,
#    'feelslike': 66.4,
#    'feelslikemax': 78.8,
#    'feelslikemin': 48.3,
#    'humidity': 37.6,
#    'icon': 'clear-day',
#    'moonphase': 0.5,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1014.6,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 25.7,
#    'solarradiation': 298.9,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:45:05',
#    'sunriseEpoch': 1647607505,
#    'sunset': '18:49:59',
#    'sunsetEpoch': 1647650999,
#    'temp': 66.7,
#    'tempmax': 80.9,
#    'tempmin': 48.3,
#    'uvindex': 10.0,
#    'visibility': 11.7,
#    'winddir': 182.2,
#    'windgust': 9.8,
#    'windspeed': 15.0},
#   {'cloudcover': 45.1,
#    'conditions': 'Partially cloudy',
#    'datetime': '2022-03-19',
#    'datetimeEpoch': 1647669600,
#    'description': 'Partly cloudy throughout the day.',
#    'dew': 48.2,
#    'feelslike': 62.2,
#    'feelslikemax': 78.9,
#    'feelslikemin': 53.0,
#    'humidity': 65.4,
#    'icon': 'partly-cloudy-day',
#    'moonphase': 0.51,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': ['rain'],
#    'pressure': 1017.8,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 23.9,
#    'solarradiation': 276.3,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:44:11',
#    'sunriseEpoch': 1647693851,
#    'sunset': '18:50:17',
#    'sunsetEpoch': 1647737417,
#    'temp': 62.2,
#    'tempmax': 78.9,
#    'tempmin': 53.0,
#    'uvindex': 10.0,
#    'visibility': 10.5,
#    'winddir': 82.8,
#    'windgust': 10.1,
#    'windspeed': 12.8},
#   {'cloudcover': 58.3,
#    'conditions': 'Partially cloudy',
#    'datetime': '2022-03-20',
#    'datetimeEpoch': 1647756000,
#    'description': 'Partly cloudy throughout the day.',
#    'dew': 41.0,
#    'feelslike': 63.6,
#    'feelslikemax': 80.0,
#    'feelslikemin': 46.4,
#    'humidity': 51.3,
#    'icon': 'partly-cloudy-day',
#    'moonphase': 0.53,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1019.2,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 24.5,
#    'solarradiation': 284.5,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:43:18',
#    'sunriseEpoch': 1647780198,
#    'sunset': '18:50:36',
#    'sunsetEpoch': 1647823836,
#    'temp': 63.8,
#    'tempmax': 80.5,
#    'tempmin': 48.3,
#    'uvindex': 10.0,
#    'visibility': 12.7,
#    'winddir': 105.7,
#    'windgust': 11.2,
#    'windspeed': 18.3},
#   {'cloudcover': 28.7,
#    'conditions': 'Partially cloudy',
#    'datetime': '2022-03-21',
#    'datetimeEpoch': 1647842400,
#    'description': 'Partly cloudy throughout the day.',
#    'dew': 34.2,
#    'feelslike': 68.1,
#    'feelslikemax': 80.1,
#    'feelslikemin': 46.5,
#    'humidity': 33.3,
#    'icon': 'partly-cloudy-day',
#    'moonphase': 0.56,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1012.0,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 26.7,
#    'solarradiation': 310.9,
#    'source': 'obs',
#    'stations': ['76625099999'],
#    'sunrise': '06:42:24',
#    'sunriseEpoch': 1647866544,
#    'sunset': '18:50:54',
#    'sunsetEpoch': 1647910254,
#    'temp': 68.6,
#    'tempmax': 82.5,
#    'tempmin': 46.5,
#    'uvindex': 10.0,
#    'visibility': 12.0,
#    'winddir': 242.6,
#    'windgust': 18.8,
#    'windspeed': 19.7},
#   {'cloudcover': 61.7,
#    'conditions': 'Partially cloudy',
#    'datetime': '2022-03-22',
#    'datetimeEpoch': 1647928800,
#    'description': 'Partly cloudy throughout the day.',
#    'dew': 23.5,
#    'feelslike': 66.5,
#    'feelslikemax': 80.0,
#    'feelslikemin': 50.1,
#    'humidity': 23.8,
#    'icon': 'partly-cloudy-day',
#    'moonphase': 0.61,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1012.9,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 27.6,
#    'solarradiation': 321.5,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:41:30',
#    'sunriseEpoch': 1647952890,
#    'sunset': '18:51:12',
#    'sunsetEpoch': 1647996672,
#    'temp': 66.9,
#    'tempmax': 82.5,
#    'tempmin': 50.1,
#    'uvindex': 10.0,
#    'visibility': 10.5,
#    'winddir': 264.6,
#    'windgust': 19.7,
#    'windspeed': 19.7},
#   {'cloudcover': 39.3,
#    'conditions': 'Partially cloudy',
#    'datetime': '2022-03-23',
#    'datetimeEpoch': 1648015200,
#    'description': 'Partly cloudy throughout the day.',
#    'dew': 23.3,
#    'feelslike': 62.4,
#    'feelslikemax': 80.0,
#    'feelslikemin': 39.3,
#    'humidity': 26.5,
#    'icon': 'partly-cloudy-day',
#    'moonphase': 0.66,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1014.5,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 28.0,
#    'solarradiation': 324.2,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:40:36',
#    'sunriseEpoch': 1648039236,
#    'sunset': '18:51:30',
#    'sunsetEpoch': 1648083090,
#    'temp': 63.1,
#    'tempmax': 82.5,
#    'tempmin': 42.9,
#    'uvindex': 10.0,
#    'visibility': 10.0,
#    'winddir': 162.5,
#    'windgust': 22.1,
#    'windspeed': 19.7},
#   {'cloudcover': 5.1,
#    'conditions': 'Clear',
#    'datetime': '2022-03-24',
#    'datetimeEpoch': 1648101600,
#    'description': 'Clear conditions throughout the day.',
#    'dew': 33.9,
#    'feelslike': 53.6,
#    'feelslikemax': 71.7,
#    'feelslikemin': 33.8,
#    'humidity': 51.2,
#    'icon': 'clear-day',
#    'moonphase': 0.71,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1019.4,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 26.7,
#    'solarradiation': 308.6,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:39:42',
#    'sunriseEpoch': 1648125582,
#    'sunset': '18:51:48',
#    'sunsetEpoch': 1648169508,
#    'temp': 54.6,
#    'tempmax': 71.7,
#    'tempmin': 37.5,
#    'uvindex': 10.0,
#    'visibility': 10.7,
#    'winddir': 85.3,
#    'windgust': 11.2,
#    'windspeed': 16.1},
#   {'cloudcover': 7.2,
#    'conditions': 'Clear',
#    'datetime': '2022-03-25',
#    'datetimeEpoch': 1648188000,
#    'description': 'Clear conditions throughout the day.',
#    'dew': 29.3,
#    'feelslike': 57.0,
#    'feelslikemax': 78.7,
#    'feelslikemin': 38.4,
#    'humidity': 40.7,
#    'icon': 'clear-day',
#    'moonphase': 0.77,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1021.1,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 28.3,
#    'solarradiation': 328.7,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:38:47',
#    'sunriseEpoch': 1648211927,
#    'sunset': '18:52:06',
#    'sunsetEpoch': 1648255926,
#    'temp': 57.7,
#    'tempmax': 78.7,
#    'tempmin': 42.7,
#    'uvindex': 10.0,
#    'visibility': 10.6,
#    'winddir': 91.7,
#    'windgust': 14.1,
#    'windspeed': 24.2},
#   {'cloudcover': 18.8,
#    'conditions': 'Clear',
#    'datetime': '2022-03-26',
#    'datetimeEpoch': 1648274400,
#    'description': 'Clear conditions throughout the day.',
#    'dew': 22.1,
#    'feelslike': 58.2,
#    'feelslikemax': 78.9,
#    'feelslikemin': 35.9,
#    'humidity': 32.0,
#    'icon': 'clear-day',
#    'moonphase': 0.83,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1019.4,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 28.9,
#    'solarradiation': 333.3,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:37:53',
#    'sunriseEpoch': 1648298273,
#    'sunset': '18:52:24',
#    'sunsetEpoch': 1648342344,
#    'temp': 58.9,
#    'tempmax': 78.9,
#    'tempmin': 39.3,
#    'uvindex': 10.0,
#    'visibility': 10.5,
#    'winddir': 95.8,
#    'windgust': 15.0,
#    'windspeed': 20.8},
#   {'cloudcover': 0.3,
#    'conditions': 'Clear',
#    'datetime': '2022-03-27',
#    'datetimeEpoch': 1648360800,
#    'description': 'Clear conditions throughout the day.',
#    'dew': 20.8,
#    'feelslike': 60.5,
#    'feelslikemax': 80.0,
#    'feelslikemin': 36.9,
#    'humidity': 24.7,
#    'icon': 'clear-day',
#    'moonphase': 0.88,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1016.5,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 28.8,
#    'solarradiation': 333.1,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:36:59',
#    'sunriseEpoch': 1648384619,
#    'sunset': '18:52:42',
#    'sunsetEpoch': 1648428762,
#    'temp': 60.9,
#    'tempmax': 82.5,
#    'tempmin': 39.1,
#    'uvindex': 10.0,
#    'visibility': 11.9,
#    'winddir': 142.5,
#    'windgust': 15.2,
#    'windspeed': 20.6},
#   {'cloudcover': 19.2,
#    'conditions': 'Clear',
#    'datetime': '2022-03-28',
#    'datetimeEpoch': 1648447200,
#    'description': 'Clear conditions throughout the day.',
#    'dew': 29.6,
#    'feelslike': 64.0,
#    'feelslikemax': 80.0,
#    'feelslikemin': 42.9,
#    'humidity': 30.7,
#    'icon': 'clear-day',
#    'moonphase': 0.92,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1014.7,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 28.0,
#    'solarradiation': 325.8,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:36:05',
#    'sunriseEpoch': 1648470965,
#    'sunset': '18:52:59',
#    'sunsetEpoch': 1648515179,
#    'temp': 64.5,
#    'tempmax': 82.5,
#    'tempmin': 42.9,
#    'uvindex': 10.0,
#    'visibility': 10.0,
#    'winddir': 178.9,
#    'windgust': 10.3,
#    'windspeed': 13.9},
#   {'cloudcover': 3.3,
#    'conditions': 'Clear',
#    'datetime': '2022-03-29',
#    'datetimeEpoch': 1648533600,
#    'description': 'Clear conditions throughout the day.',
#    'dew': 33.5,
#    'feelslike': 68.6,
#    'feelslikemax': 82.4,
#    'feelslikemin': 48.3,
#    'humidity': 29.3,
#    'icon': 'clear-day',
#    'moonphase': 0.96,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1012.9,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 28.3,
#    'solarradiation': 327.7,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:35:12',
#    'sunriseEpoch': 1648557312,
#    'sunset': '18:53:17',
#    'sunsetEpoch': 1648601597,
#    'temp': 69.3,
#    'tempmax': 85.7,
#    'tempmin': 48.3,
#    'uvindex': 10.0,
#    'visibility': 10.8,
#    'winddir': 240.9,
#    'windgust': 11.6,
#    'windspeed': 13.9},
#   {'cloudcover': 25.8,
#    'conditions': 'Partially cloudy',
#    'datetime': '2022-03-30',
#    'datetimeEpoch': 1648620000,
#    'description': 'Partly cloudy throughout the day.',
#    'dew': 27.9,
#    'feelslike': 69.2,
#    'feelslikemax': 83.9,
#    'feelslikemin': 51.9,
#    'humidity': 23.4,
#    'icon': 'partly-cloudy-day',
#    'moonphase': 0.99,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1009.9,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 28.8,
#    'solarradiation': 333.4,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:34:18',
#    'sunriseEpoch': 1648643658,
#    'sunset': '18:53:35',
#    'sunsetEpoch': 1648688015,
#    'temp': 70.1,
#    'tempmax': 87.5,
#    'tempmin': 51.9,
#    'uvindex': 10.0,
#    'visibility': 11.2,
#    'winddir': 270.2,
#    'windgust': 19.9,
#    'windspeed': 21.9},
#   {'cloudcover': 23.9,
#    'conditions': 'Partially cloudy',
#    'datetime': '2022-03-31',
#    'datetimeEpoch': 1648706400,
#    'description': 'Becoming cloudy in the afternoon.',
#    'dew': 23.6,
#    'feelslike': 68.1,
#    'feelslikemax': 83.6,
#    'feelslikemin': 50.1,
#    'humidity': 21.3,
#    'icon': 'partly-cloudy-day',
#    'moonphase': 1.0,
#    'precip': 0.0,
#    'precipcover': None,
#    'precipprob': 0.0,
#    'preciptype': None,
#    'pressure': 1009.9,
#    'severerisk': 10.0,
#    'snow': 0.0,
#    'snowdepth': 0.0,
#    'solarenergy': 29.0,
#    'solarradiation': 337.0,
#    'source': 'obs',
#    'stations': ['MMQT', '76625099999'],
#    'sunrise': '06:33:24',
#    'sunriseEpoch': 1648730004,
#    'sunset': '18:53:53',
#    'sunsetEpoch': 1648774433,
#    'temp': 68.8,
#    'tempmax': 87.0,
#    'tempmin': 50.1,
#    'uvindex': 10.0,
#    'visibility': 11.5,
#    'winddir': 204.2,
#    'windgust': 10.5,
#    'windspeed': 15.0}],
#  'latitude': 20.835996656,
#  'longitude': -99.85082993,
#  'queryCost': 31,
#  'resolvedAddress': '20.835996656,-99.85082993',
#  'stations': {'76625099999': {'contribution': 0.0,
#    'distance': 42549.0,
#    'id': '76625099999',
#    'latitude': 20.617,
#    'longitude': -100.186,
#    'name': 'QUERETARO INTERCONTINENTAL, MX',
#    'quality': 66,
#    'useCount': 0},
#   'MMQT': {'contribution': 0.0,
#    'distance': 41865.0,
#    'id': 'MMQT',
#    'latitude': 20.62,
#    'longitude': -100.18,
#    'name': 'MMQT',
#    'quality': 8,
#    'useCount': 0}},
#  'timezone': 'America/Mexico_City',
#  'tzoffset': -6.0}

# %%
# Podemos ver que la llave "days" contiene todos los datos climáticos 
# que necesitamos. Corroboramos que sean los 31 días que recolectamos
print(f'Número de días recolectados: {len(json_response["days"])}')
# Out:
# Número de días recolectados: 31

# %% [markdown]
# **<h3>1.2 Propiedades:</h3>**
#
# Ya que entendemos como están organizados los datos climatológicos de la API podemos proceder con el entendimiento de los datos de las propiedades.
# <br></br>
# Se hará un análisis exploratorio de los datos de propiedades para poder responder las preguntas del desafío:

# %%
properties = pd.read_csv('properties.csv')
print(properties.info())
print(properties.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_id    80 non-null     int64
#  1   type_house     80 non-null     object
#  2   business_type  80 non-null     object
#  3   bedrooms       80 non-null     int64
#  4   bathrooms      80 non-null     int64
#  5   parking_lots   80 non-null     int64
#  6   services       19 non-null     float64
#  7   balcony        80 non-null     int64
#  8   pool           80 non-null     bool
#  9   latitude       80 non-null     float64
#  10  longitude      80 non-null     float64
#  11  localidad      80 non-null     object
#  12  city           80 non-null     object
#  13  region         80 non-null     object
#  14  country        80 non-null     object
# dtypes: bool(1), float64(3), int64(5), object(6)
# memory usage: 9.0+ KB
# None
#        property_id   bedrooms  bathrooms  parking_lots       services  \
# count      80.0000  80.000000  80.000000     80.000000      19.000000
# mean       40.5000   2.275000   1.725000      0.650000    5264.526316
# std        23.2379   0.871126   0.655551      0.713345   22941.242048
# min         1.0000   1.000000   1.000000      0.000000       0.000000
# 25%        20.7500   2.000000   1.000000      0.000000       0.000000
# 50%        40.5000   2.000000   2.000000      1.000000       1.000000
# 75%        60.2500   3.000000   2.000000      1.000000       3.000000
# max        80.0000   5.000000   4.000000      2.000000  100000.000000
#
#          balcony   latitude  longitude
# count  80.000000  80.000000  80.000000
# mean    0.137500   4.685079 -74.116246
# std     0.346547   0.062736   0.062496
# min     0.000000   4.586188 -74.245544
# 25%     0.000000   4.644076 -74.158101
# 50%     0.000000   4.685236 -74.111243
# 75%     0.000000   4.722041 -74.057694
# max     1.000000   4.926684 -74.023470

# %% [markdown]
# Se puede ver que se tienen 80 propiedades registradas. Algunos insights que podemos  ver son los siguientes:
#
# <ul>
#   <li>Vemos que 61 propiedades no cuentan con servicios.</li>
#   <li>Pareciera que las propiedades más grandes tienen 5 cuartos, 2 estacionamientos y hasta 4 baños. Una hipótesis de correlación con el precio  sería interesante de comprobar.</li>
#   <li>Las propiedades más pequeñas tienen 1 cuarto, 1 estacionamiento y 1 baño.</li>
# </ul>

# %% [markdown]
# **<h3>1.3 Usuarios:</h3>**
#
# Vamos a dar un entendimiento superficial de los datos de los usuarios.

# %%
users = pd.read_csv('users.csv')
print(users.info())
print(users.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   property_id  80 non-null     int64
#  1   user_id      80 non-null     int64
#  2   first_name   80 non-null     object
#  3   last_name    80 non-null     object
#  4   address      80 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 3.2+ KB
# None
#        property_id  user_id
# count      80.0000  80.0000
# mean       40.5000  40.5000
# std        23.2379  23.2379
# min         1.0000   1.0000
# 25%        20.7500  20.7500
# 50%        40.5000  40.5000
# 75%        60.2500  60.2500
# max        80.0000  80.0000

# %% [markdown]
# Se observa que se tienen 80 usuarios, una cantidad igual al número de propiedades. En primera instancia, pareciera que cada propiedad pertenece a un solo usuario. Es decir, en nuestro modelo de datos se tiene una relación 1 a 1. Aún así, sería bueno comprobar que esta relación sea correcta.
#
# Algo interesante que se podría hacer es extraer la dirección del usuario y calcular su ubicación geográfica, de tal forma que podamos ver la cercanía del usuario respecto a la propiedad.

# %% [markdown]
# **<h3>1.4 Visitas:</h3>**
#
# Vamos a dar un entendimiento superficial de los datos de las visitas.

# %%
visits = pd.read_csv('visits.csv')
print(visits.info())
print(visits.describe())
print('Fecha de ingreso de la primera visita: ', visits.begin_date.min())
print('Fecha de ingreso de la última visita: ', visits.begin_date.max())
print('Valores de status: ', visits.status.unique())
print('Valores de tipo de visita: ', visits.type_visit.unique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425 entries, 0 to 424
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   scheduled_id  425 non-null    int64
#  1   property_id   425 non-null    int64
#  2   begin_date    425 non-null    object
#  3   end_date      425 non-null    object
#  4   type_visit    425 non-null    object
#  5   status        425 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 20.0+ KB
# None
#         scheduled_id  property_id
# count     425.000000   425.000000
# mean   188094.894118    40.087059
# std     13820.402675    22.943521
# min    160130.000000     1.000000
# 25%    176671.000000    21.000000
# 50%    190273.000000    38.000000
# 75%    200307.000000    61.000000
# max    208926.000000    80.000000
# Fecha de ingreso de la primera visita:  2022-01-01T16:00:00-03:00
# Fecha de ingreso de la última visita:  2022-02-28T21:00:00-03:00
# Valores de status:  ['Cancelled' 'Done']
# Valores de tipo de visita:  ['Visit']

# %% [markdown]
# En este caso, vemos que nuestra relación es de uno a varios. Es decir, que se tienen varias visitas por propiedad. Además, algo interesante sería calcular el tiempo de estadía promedio de los visitantes en las propiedades.

# %% [markdown]
# **<h1>2. Preguntas del desafío:</h1>**
#
# **<h3>2.1. ¿Cuántas visitas se realizaron en total?</h3>**
#
# Si bien la pregunta no especifica, es importante destacar la diferencia entre visitas totales las cuales incluyen tanto las canceladas como las realizadas.
#
# Para contestar esta pregunta se realizará el cálculo para los tres casos:
# <ul>
#   <li>Canceladas y realizadas</li>
#   <li>Canceladas</li>
#   <li>Realizadas</li>
# </ul>

# %%
# Primer caso: total = canceladas + realizadas
num_total_visits = len(visits)
print(f'Total: {num_total_visits}')
num_cancelled_visits = len(visits.loc[visits["status"] == "Cancelled"])
print(f'Canceladas: {num_cancelled_visits}')
num_done_visits = len(visits.loc[visits["status"] == "Done"])
print(f'Realizadas: {num_done_visits}')

# Verificamos que haga sentido el cálculo
print(num_total_visits == num_done_visits + num_cancelled_visits)
# Out:
# Total: 425
# Canceladas: 286
# Realizadas: 139
# True

# %% [markdown]
# **RESPUESTA :**
#
# <ul>
# <li>Total de visitas: 425</li>
# <li>Visitas Canceladas: 286</li>
# <li>Visitas Realizadas: 139</li>
# </ul>

# %% [markdown]
# **<h3>2.2. ¿Cuál es el promedio de propiedades por usuario?</h3>**
#
# Para responder esta pregunta lo primero que tenemos que hacer es verificar el número de propiedades únicas por ID en la tabla de "properties" y compararlo con el número de propiedades únicas en la tabla de "users". De esta manera nos aseguramos si es una correspondencia 1 a 1.

# %%
unique_properties = set(properties.property_id.unique())
print(f'Número de propiedades por ID únicas: {len(unique_properties)}')

unique_properties_in_users = set(users.property_id.unique())
print(f'Número de propiedades por ID únicas: {len(unique_properties)}')

print(f'Do we have the same properties? --> {unique_properties == unique_properties_in_users}')
# Out:
# Número de propiedades por ID únicas: 80
# Número de propiedades por ID únicas: 80
# Do we have the same properties? --> True

# %% [markdown]
# Con esto podemos hacer una agrupación por usuario y contar el número de propiedades que tiene cada usuario. De esta forma podremos sacar el promedio de propiedades por usuario:

# %%
num_properties_by_user = users.groupby(by='user_id').property_id.count()
print(num_properties_by_user)
print(f'\nPromedio de propiedades por usuario: {num_properties_by_user.mean()}')
# Out:
# user_id
# 1     1
# 2     1
# 3     1
# 4     1
# 5     1
#      ..
# 76    1
# 77    1
# 78    1
# 79    1
# 80    1
# Name: property_id, Length: 80, dtype: int64
#
# Promedio de propiedades por usuario: 1.0

# %% [markdown]
# **RESPUESTA :**
#
# <ul>
# <li>Número de propiedades por usuario: 1</li>
# </ul>

# %% [markdown]
# **<h3>2.3. ¿Cuál era la temperatura promedio de todas las visitas que realizó el usuario con ID 2?</h3>**
#
# Para responder esta pregunta, lo primero que tenemos que hacer es realizar un right join donde la tabla izquierda sería la de usuarios y la tabla de la derecha sería la de visitas. La razón radica en que por usuario tenemos una sola propiedad y por propiedad tenemos varias visitas.
#
# Aún así, queremos tener toda la información disponible (usuarios, propiedades y visitas) en una sola tabla ya que requerimos las latitudes y longitudes para extraer las temperaturas por usuario. Así entonces haremos dos joins consecutivos lo que nos permitirá saber todas las visitas realizadas de un determinado usuario.

# %%
# Garantizamos que sean las mismas propiedades 
# también para la tabla de visits.
print('\nSon las mismas propiedades en las tres tablas? --> ' ,
      set(visits.property_id) == set(properties.property_id) == set(users.property_id))
print()

# Hacemos el primer inner join entre "users" y "properties"
users_and_properties = pd.merge(left=users, 
                                right=properties, 
                                how='inner', 
                                on=['property_id', 'property_id'])
print(users_and_properties.info())
print()

# Hacemos el segundo join con "visits"
houm_data = pd.merge(left=users_and_properties, 
                     right=visits, 
                     how='right',
                     on='property_id')
print(houm_data.info())
# Out:
# Son las mismas propiedades en las tres tablas? -->  True
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80 entries, 0 to 79
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_id    80 non-null     int64
#  1   user_id        80 non-null     int64
#  2   first_name     80 non-null     object
#  3   last_name      80 non-null     object
#  4   address        80 non-null     object
#  5   type_house     80 non-null     object
#  6   business_type  80 non-null     object
#  7   bedrooms       80 non-null     int64
#  8   bathrooms      80 non-null     int64
#  9   parking_lots   80 non-null     int64
#  10  services       19 non-null     float64
#  11  balcony        80 non-null     int64
#  12  pool           80 non-null     bool
#  13  latitude       80 non-null     float64
#  14  longitude      80 non-null     float64
#  15  localidad      80 non-null     object
#  16  city           80 non-null     object
#  17  region         80 non-null     object
#  18  country        80 non-null     object
# dtypes: bool(1), float64(3), int64(6), object(9)
# memory usage: 12.0+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 425 entries, 0 to 424
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_id    425 non-null    int64
#  1   user_id        425 non-null    int64
#  2   first_name     425 non-null    object
#  3   last_name      425 non-null    object
#  4   address        425 non-null    object
#  5   type_house     425 non-null    object
#  6   business_type  425 non-null    object
#  7   bedrooms       425 non-null    int64
#  8   bathrooms      425 non-null    int64
#  9   parking_lots   425 non-null    int64
#  10  services       107 non-null    float64
#  11  balcony        425 non-null    int64
#  12  pool           425 non-null    bool
#  13  latitude       425 non-null    float64
#  14  longitude      425 non-null    float64
#  15  localidad      425 non-null    object
#  16  city           425 non-null    object
#  17  region         425 non-null    object
#  18  country        425 non-null    object
#  19  scheduled_id   425 non-null    int64
#  20  begin_date     425 non-null    object
#  21  end_date       425 non-null    object
#  22  type_visit     425 non-null    object
#  23  status         425 non-null    object
# dtypes: bool(1), float64(3), int64(7), object(13)
# memory usage: 80.1+ KB
# None

# %% [markdown]
# Ahora si obtenemos las propiedades y visitas del usuario con ID 2:

# %%
user_2_data = houm_data.loc[houm_data['user_id'] == 2]
user_2_data
# Out:
#      property_id  user_id first_name last_name               address  \
# 177           34        2        Art    Venere  8 W Cerritos Ave #54
# 178           34        2        Art    Venere  8 W Cerritos Ave #54
# 179           34        2        Art    Venere  8 W Cerritos Ave #54
# 180           34        2        Art    Venere  8 W Cerritos Ave #54
# 181           34        2        Art    Venere  8 W Cerritos Ave #54
# 182           34        2        Art    Venere  8 W Cerritos Ave #54
# 183           34        2        Art    Venere  8 W Cerritos Ave #54
#
#        type_house business_type  bedrooms  bathrooms  parking_lots  ...  \
# 177  departamento        Rental         1          1             0  ...
# 178  departamento        Rental         1          1             0  ...
# 179  departamento        Rental         1          1             0  ...
# 180  departamento        Rental         1          1             0  ...
# 181  departamento        Rental         1          1             0  ...
# 182  departamento        Rental         1          1             0  ...
# 183  departamento        Rental         1          1             0  ...
#
#      longitude    localidad    city                  region   country  \
# 177   -74.0735  Teusaquillo  Bogotá  Región De Cundinamarca  Colombia
# 178   -74.0735  Teusaquillo  Bogotá  Región De Cundinamarca  Colombia
# 179   -74.0735  Teusaquillo  Bogotá  Región De Cundinamarca  Colombia
# 180   -74.0735  Teusaquillo  Bogotá  Región De Cundinamarca  Colombia
# 181   -74.0735  Teusaquillo  Bogotá  Región De Cundinamarca  Colombia
# 182   -74.0735  Teusaquillo  Bogotá  Región De Cundinamarca  Colombia
# 183   -74.0735  Teusaquillo  Bogotá  Región De Cundinamarca  Colombia
#
#     scheduled_id                 begin_date                   end_date  \
# 177       186033  2022-01-29T12:00:00-03:00  2022-01-29T14:00:00-03:00
# 178       187080  2022-01-28T11:00:00-03:00  2022-01-29T01:00:00-03:00
# 179       186857  2022-01-28T11:30:00-03:00  2022-01-28T14:00:00-03:00
# 180       180698  2022-01-22T20:00:00-03:00  2022-01-22T22:00:00-03:00
# 181       177506  2022-01-23T13:00:00-03:00  2022-01-23T15:00:00-03:00
# 182       178172  2022-01-21T18:00:00-03:00  2022-01-21T20:00:00-03:00
# 183       177505  2022-01-23T09:00:00-03:00  2022-01-23T11:00:00-03:00
#
#     type_visit     status
# 177      Visit  Cancelled
# 178      Visit       Done
# 179      Visit       Done
# 180      Visit  Cancelled
# 181      Visit  Cancelled
# 182      Visit  Cancelled
# 183      Visit  Cancelled
#
# [7 rows x 24 columns]

# %% [markdown]
# Observamos que es la misma propiedad en las 7 visitas, por lo que lo único que cambia son las fechas en las que ingreso y salió en cada visita. Realizaremos una función que nos permitirá extraer la temperatura promedio en un rango de fechas específico y para una latitud y longitud concretas:

# %%
def get_tmp_avg_by_date_range(start_date: str, 
                              end_date: str, 
                              lat: float, 
                              lng: float) -> float:
  """
    Returns the average temperature value for a specific time interval
    specified between a starting date and an ending date. Furthermore,
    it extracts the average temperature from the corresponding location
    specified by latitude and longitude coordinates.

    API used: https://www.visualcrossing.com/weather-api 

    params: 
      start_date: starting date with string format 'YYYY-MM-dd'
      end_date:   ending date with string format 'YYYY-MM-dd' 
      lat:        latitude coordinate
      lng:        longitude coordinate
    
    returns
      avg_temp: average temperature in the specific time interval and location. 
  """

  # Get data from API 
  with open('api_key.txt', 'r') as f:
    API_KEY = f.readlines()[0]
  response = requests.get(f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{lat},{lng}/{start_date}/{end_date}?key={API_KEY}&include=days")
  json_response = response.json()

  # Extract all temperatures registered in that time interval
  climate_days = json_response["days"]
  temperatures = [climate_day['temp'] for climate_day in climate_days]

  # Return mean temperature
  return np.mean(temperatures)

# Testing the function using the first visit of user 2
first_visit = user_2_data.iloc[0]
first_visit_start_date = first_visit.begin_date.split('T')[0]
first_visit_end_date = first_visit.end_date.split('T')[0]
first_visit_lat = first_visit.latitude
first_visit_lng = first_visit.longitude

avg_tmp_first_visit = get_tmp_avg_by_date_range(start_date=first_visit_start_date, 
                                                end_date=first_visit_end_date,
                                                lat=first_visit_lat, 
                                                lng=first_visit_lng)
print(f'First visit average temperature: {avg_tmp_first_visit}')
# Out:
# First visit average temperature: 56.1

# %% [markdown]
# Ya que pudimos encapsular la lógica para obtener la temperatura promedio por visita, ahora podemos usarla para sacar las temperaturas promedios de todas las visitas de cualquier usuario:

# %%
def get_avg_tmp_visit(data: pd.DataFrame, 
                      user_id: int, 
                      scheduled_id: int) -> float:
  """
    Returns the average temperature for the ellapsed time for a specific visit 
    related to any user.

    params: 
      data:           DataFrame containing data of properties, users and visits
      user_id:        id for a specific user. 
      scheduled_id:   id to recognize a specific visit 
    
    returns
      avg_temp: average temperature of a specific visit related to a user.
  """

  # Extract data related to the specific user
  user_data = houm_data.loc[houm_data['user_id'] == user_id]

  # Get visit dates and location of the property to extract temperature
  visit = user_data.loc[user_data['scheduled_id'] == scheduled_id]
  visit_start_date = visit.begin_date.values[0].split('T')[0]
  visit_end_date = visit.end_date.values[0].split('T')[0]
  visit_lat = visit.latitude.values[0]
  visit_lng = visit.longitude.values[0]

  # Extract mean temperature
  avg_tmp_visit = get_tmp_avg_by_date_range(start_date=visit_start_date,
                                            end_date=visit_end_date,
                                            lat=visit_lat,
                                            lng=visit_lng)
  
  return avg_tmp_visit
  
# Testing the function for a random visit of user 2
user_id = 2
random_idx = np.random.choice(len(user_2_data))
scheduled_id = user_2_data.iloc[random_idx].scheduled_id
print(f'Random scheduled id: {scheduled_id}')

avg_visit_tmp = get_avg_tmp_visit(houm_data,
                                  user_id=user_id,
                                  scheduled_id=scheduled_id)
print(avg_visit_tmp)
# Out:
# Random scheduled id: 187080
# 57.2

# %% [markdown]
# Finalmente podemos usar está última función para encontrar la respuesta final: la temperatura promedio de todas las visitas que realizó el usuario 2. De hecho, esta lógica nos permite dar respuesta para cualquier usuario en los datos.

# %%
#Input
user_id = 2

# Get user data
user_data = houm_data.loc[houm_data['user_id'] == user_id]
scheduled_ids = user_data['scheduled_id'].to_list()

# Extract average temperature per each visit for that user
avg_visit_tmps = {}
for scheduled_id in scheduled_ids:
  avg_visit_tmps[scheduled_id] = get_avg_tmp_visit(houm_data,
                                                   user_id=user_id,
                                                   scheduled_id=scheduled_id)
  
print(f'Temperatures per visit for user {user_id}: {avg_visit_tmps}')
print(f'Mean temperature for all visits: {np.mean(np.mean(list(avg_visit_tmps.values())))}')
# Out:
# Temperatures per visit for user 2: {186033: 56.1, 187080: 57.2, 186857: 58.3, 180698: 58.1, 177506: 59.3, 178172: 57.7, 177505: 59.3}
# Mean temperature for all visits: 58.0

# %% [markdown]
# **RESPUESTA :**
#
# <ul>
# <li>Temperatura promedio de todas las visitas que realizó el usuario con ID 2: 58.0</li>
# </ul>

# %% [markdown]
# **<h3>2.4. ¿Cuál es la temperatura promedio de las visitas para los días con lluvia??</h3>**
#
# Lo primero que se puede hacer para saber si hay lluvia es revisar dos campos en la API:
#
# <ul>
#   <li>condition</li>
#   <li>precip</li>
# </ul>
#
# Para eso vamos a extraer todos los días de un mes y ver si en efecto esos dos campos nos permitirían saber si llovió o no.

# %%
start_date = '2022-02-01'
end_date = '2022-02-28'

with open('api_key.txt', 'r') as f:
  API_KEY = f.readlines()[0]

response = requests.get(f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{lat},{lng}/{start_date}/{end_date}?key={API_KEY}&include=days")
json_response = response.json()
print(f'Número de días recolectados: {len(json_response["days"])}')
# Out:
# Número de días recolectados: 28

# %%
# Extraemos ambos campos y vemos los valores únicos
rain_data = {day['datetime']: {'condition': day['conditions'], 'precip': day['precip']}
             for day in json_response["days"]}
rain_df = pd.DataFrame.from_dict(rain_data).T
print(rain_df.head(5))
print(f'Unique conditions: {rain_df.condition.value_counts()}')
# Out:
#                          condition precip
# 2022-02-01  Rain, Partially cloudy   0.06
# 2022-02-02  Rain, Partially cloudy   0.08
# 2022-02-03  Rain, Partially cloudy   0.06
# 2022-02-04  Rain, Partially cloudy   0.11
# 2022-02-05  Rain, Partially cloudy   0.17
# Unique conditions: Rain, Partially cloudy    28
# Name: condition, dtype: int64

# %% [markdown]
# Vemos que si podemos usar el campo "condition" para extraer aquellos días que fueron lluviosos. Por lo tanto, vamos a hacer la lógica que nos permita extraer todas aquellas visitas que tuvieron lluvia.

# %%
def get_rainy_visits(data: pd.DataFrame) -> pd.DataFrame:
  """
    Returns a DataFrame with all visits when it rained.

    params: 
      data:           DataFrame containing data of properties, users and visits
    
    returns
      rainy_visits:   DataFrame with all visits when it rained. 
  """

  # Getting API key
  with open('api_key.txt', 'r') as f:
    API_KEY = f.readlines()[0]

  # Initializing list of visits when it rained
  rainy_visits = []

  # Let us process each visit individually to determine whether it rained or not
  # during that date
  for i in tqdm(range(len(data))):

    # Get visit data
    visit = data.iloc[i]
    lat = visit['latitude']
    lng = visit['longitude']
    start_date = visit['begin_date'].split('T')[0]
    end_date = visit['end_date'].split('T')[0]

    # Get data from API using visit dates and location
    response = requests.get(f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{lat},{lng}/{start_date}/{end_date}?key={API_KEY}&include=days")
    json_response = response.json()

    # Extract all climate data registered in time interval
    climate_days = json_response["days"]

    # Define array of ones and zeros where each position represents a day. 
    # One represents that it rained at least one day 0 means it did not rain
    rain_array =  np.array([  1 if 'rain' in day['conditions'].lower() 
                              else 0 
                              for day in climate_days ])
    
    it_rained = np.isin(1, rain_array).tolist()

    if it_rained:
      # We add rainy conditions and temperature
      visit = visit.append(pd.Series({'rainy_conditions': 
                                      str([day['conditions'] for day in climate_days ])}))
      visit = visit.append(pd.Series({'temperature':
                                      np.mean([day['temp'] for day in json_response['days']])}))
      rainy_visits.append(visit)

  return rainy_visits

# Test function
rainy_visits = get_rainy_visits(houm_data)

print(f'Número de visitas lluviosas: {len(rainy_visits)}')
print(f'Total de visitas lluviosas: {len(houm_data)}')
# Out:
# 100%|██████████| 425/425 [00:46<00:00,  9.06it/s]
# Número de visitas lluviosas: 379
# Total de visitas lluviosas: 425

# %% [markdown]
# Si vemos el número de días que llovieron podemos ver que fueron 379, lo cual representa una gran proporción de días lluviosos. Por lo tanto, se hará una verificación sacando la estadística de ubicaciones y días de todas las visitas en las que llovió.

# %%
# Transform list of Series to DataFrame for an easier manipulation
rainy_visits_df = pd.concat(rainy_visits, axis=1, keys=[s.name for s in rainy_visits]).T

print(f'\nNúmero de días de lluvia por ubicación:\n\n{rainy_visits_df.address.value_counts()}')
print(f'\nDías cuando llovío:\n\n{rainy_visits_df.begin_date.str.split("T").str[0].value_counts()}')
print('\nTodas las condiciones de lluvia en eso días y ubicaciones:\n')
rainy_visits_df.rainy_conditions.unique()
# Out:
# Número de días de lluvia por ubicación:
#
# 1088 Pinehurst St       10
# 762 S Main St           10
# 34 Center St            10
# 322 New Horizon Blvd     9
# 775 W 17th St            9
#                         ..
# 128 Bransten Rd          1
# 6 Kains Ave              1
# 4545 Courthouse Rd       1
# 2 Cedar Ave #84          1
# 74874 Atlantic Ave       1
# Name: address, Length: 76, dtype: int64
#
# Días cuando llovío:
#
# 2022-02-12    19
# 2022-02-28    15
# 2022-02-21    14
# 2022-01-23    14
# 2022-01-14    14
# 2022-02-19    13
# 2022-02-26    13
# 2022-01-10    12
# 2022-01-20    11
# 2022-02-02    10
# 2022-02-24    10
# 2022-01-24    10
# 2022-02-05     9
# 2022-02-07     9
# 2022-01-17     9
# 2022-01-18     9
# 2022-02-20     9
# 2022-01-26     8
# 2022-02-08     8
# 2022-02-13     8
# 2022-01-13     8
# 2022-02-27     8
# 2022-02-03     8
# 2022-02-17     8
# 2022-01-11     8
# 2022-02-16     8
# 2022-01-21     7
# 2022-01-29     7
# 2022-01-28     7
# 2022-02-22     6
# 2022-02-06     6
# 2022-01-12     6
# 2022-01-15     6
# 2022-01-25     6
# 2022-02-14     5
# 2022-02-15     5
# 2022-02-18     5
# 2022-02-23     5
# 2022-02-11     5
# 2022-02-10     5
# 2022-02-04     5
# 2022-01-16     4
# 2022-01-27     4
# 2022-01-22     3
# 2022-01-19     3
# 2022-02-09     2
# 2022-02-01     2
# 2022-02-25     2
# 2022-01-09     1
# Name: begin_date, dtype: int64
#
# Todas las condiciones de lluvia en eso días y ubicaciones:
# array(["['Rain, Partially cloudy']",
#        "['Partially cloudy', 'Rain, Partially cloudy']",
#        "['Rain, Partially cloudy', 'Rain, Partially cloudy']"],
#       dtype=object)

# %% [markdown]
# Con esto garantizamos que llovió en todas esas ubicaciones y en esos días. Ahora procedemos a calcular la temperatura promedio:

# %%
print(f'\nNúmero de temperaturas promedio por visitas que tuvieron lluvia:\n {len(rainy_visits_df)}')
print(f'\nTodas las temperaturas promedio:\n {rainy_visits_df.temperature.to_list()}')
print(f'\nTemperatura promedio global:\n {rainy_visits_df.temperature.mean()}')
# Out:
# Número de temperaturas promedio por visitas que tuvieron lluvia:
#  379
#
# Todas las temperaturas promedio:
#  [55.1, 58.9, 58.1, 59.0, 59.0, 55.1, 57.7, 55.1, 55.8, 58.2, 58.2, 56.1, 56.1, 55.2, 55.7, 57.6, 56.1, 57.7, 56.0, 55.2, 58.1, 59.0, 56.0, 55.5, 56.0, 56.1, 56.0, 57.3, 55.3, 56.0, 55.3, 57.7, 56.0, 55.9, 58.0, 58.0, 55.5, 58.8, 57.8, 59.1, 57.5, 58.0, 57.5, 55.4, 56.0, 57.4, 55.9, 57.2, 55.9, 55.9, 55.8, 59.3, 57.7, 59.1, 58.2, 58.2, 59.3, 57.7, 56.1, 55.4, 57.35, 56.2, 57.3, 56.2, 57.3, 54.9, 56.3, 57.5, 56.3, 58.0, 56.1, 58.0, 58.2, 56.1, 56.75, 55.9, 55.1, 57.7, 57.7, 55.9, 55.9, 57.4, 55.4, 57.6, 56.0, 56.0, 56.0, 59.6, 59.6, 55.6, 57.4, 58.0, 58.0, 58.0, 58.8, 57.9, 57.2, 54.8, 57.5, 57.4, 57.7, 55.9, 55.9, 57.5, 56.0, 56.4, 56.4, 56.4, 56.4, 59.5, 59.4, 55.2, 55.5, 58.0, 59.2, 59.2, 57.8, 57.9, 57.5, 55.5, 56.1, 55.7, 56.0, 56.3, 55.7, 57.6, 57.8, 57.7, 56.3, 56.3, 57.3, 57.3, 58.0, 56.1, 57.2, 58.3, 58.1, 59.3, 57.7, 59.3, 59.1, 58.0, 58.0, 58.0, 58.0, 57.5, 57.8, 57.2, 57.2, 57.2, 58.0, 57.8, 58.0, 58.0, 59.1, 57.7, 57.5, 55.5, 57.8, 59.1, 59.1, 59.1, 57.5, 59.1, 57.5, 57.8, 55.8, 57.3, 55.9, 57.5, 55.4, 57.3, 57.3, 56.6, 54.9, 56.6, 57.2, 57.1, 58.7, 58.0, 58.0, 58.3, 57.1, 57.8, 56.4, 55.8, 56.9, 56.4, 59.2, 57.5, 55.7, 59.5, 59.6, 59.6, 59.6, 59.5, 59.5, 55.5, 57.2, 59.0, 57.2, 55.5, 55.8, 55.8, 55.3, 59.6, 59.5, 59.5, 56.0, 58.7, 58.7, 59.3, 59.5, 56.5, 59.3, 56.4, 57.0, 57.5, 55.6, 58.8, 58.8, 59.0, 59.0, 57.4, 57.4, 57.6, 57.2, 55.5, 57.3, 55.5, 57.3, 57.1, 57.3, 57.3, 59.2, 57.5, 59.4, 56.3, 54.5, 54.5, 56.4, 56.4, 56.4, 54.4, 57.8, 55.35, 57.4, 55.8, 55.8, 55.7, 55.3, 59.6, 59.6, 57.9, 56.6, 55.6, 57.3, 56.6, 55.7, 58.0, 56.3, 59.5, 56.4, 57.1, 56.4, 59.1, 59.2, 59.5, 55.7, 55.6, 59.1, 59.1, 56.4, 57.7, 57.2, 55.2, 57.3, 57.6, 57.3, 57.6, 57.6, 57.1, 59.4, 59.4, 59.4, 59.4, 59.4, 59.4, 57.6, 57.650000000000006, 57.9, 56.5, 55.7, 57.4, 57.4, 57.4, 57.4, 59.2, 59.3, 59.3, 57.6, 59.5, 59.5, 57.9, 57.1, 57.1, 59.0, 57.4, 57.4, 56.4, 55.8, 58.0, 56.4, 58.9, 57.5, 57.4, 57.1, 59.3, 56.9, 57.9, 58.6, 56.9, 56.9, 56.5, 56.5, 56.5, 57.4, 57.1, 59.1, 59.1, 57.2, 57.2, 59.3, 58.0, 55.6, 58.6, 55.6, 55.6, 57.1, 57.1, 58.0, 56.35, 58.2, 58.2, 55.8, 55.8, 58.0, 57.0, 58.2, 58.2, 58.2, 56.1, 56.1, 58.2, 58.2, 58.2, 58.2, 56.1, 56.1, 57.2, 58.5, 58.5, 58.1, 58.1, 58.4, 58.4, 55.8, 55.8, 55.8, 57.0, 56.2, 56.2, 56.2, 57.2, 57.2, 56.2, 58.3, 57.2, 57.2]
#
# Temperatura promedio global:
#  57.30725593667546

# %% [markdown]
# **RESPUESTA:**
#
# Temperatura promedio de las visitas para los días con lluvia: 57.30725593667546

# %% [markdown]
# **<h3>2.5. ¿Cuál es la temperatura promedio para las visitas realizadas en la localidad de Suba?</h3>**
#
# Esta pregunta se puede responder haciendo una segmentación de datos solo de la localidad mencionada. Este código nos sirve para obtener la temperatura promedio de todas las visitas hechas en cualquier localidad.

# %%
# Input
location = 'Suba'

# Initializing visits from that location with average temperatures
location_visits_with_temp = []

# Get all data from the specified location
location_data = houm_data.loc[houm_data['localidad'] == location]
print(f'Total number of registries for location of {location}: {len(location_data)}')

# Getting API key
with open('api_key.txt', 'r') as f:
  API_KEY = f.readlines()[0]

# Let us use our previous definition to extract average temperatures
for i in tqdm(range(len(location_data))):
  
  # Get visit data
  visit = location_data.iloc[i]
  lat = visit['latitude']
  lng = visit['longitude']
  start_date = visit['begin_date'].split('T')[0]
  end_date = visit['end_date'].split('T')[0]

  # Get data from API using visit dates and location
  response = requests.get(f"https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/{lat},{lng}/{start_date}/{end_date}?key={API_KEY}&include=days")
  json_response = response.json()

  # Extract all climate data registered in time interval
  climate_days = json_response["days"]

  # We use our previous definition
  avg_tmp = get_tmp_avg_by_date_range(start_date=start_date,
                                      end_date=end_date,
                                      lat=lat,
                                      lng=lng)
  
  # Add average temperature
  visit = visit.append(pd.Series({'temperature': avg_tmp}))
  location_visits_with_temp.append(visit)
  
location_visits_with_temp_df = pd.concat(location_visits_with_temp, 
                                         axis=1, 
                                         keys=[s.name for s in location_visits_with_temp]).T

print(location_visits_with_temp_df.head(5))
# Out:
# Total number of registries for location of Suba: 86
# 100%|██████████| 86/86 [00:19<00:00,  4.39it/s]
#     property_id user_id first_name last_name           address    type_house  \
# NaN           4      23    Maryann   Royster  74 S Westgate St  departamento
# NaN           9      27    Ezekiel      Chui   2 Cedar Ave #84  departamento
# NaN           9      27    Ezekiel      Chui   2 Cedar Ave #84  departamento
# NaN           9      27    Ezekiel      Chui   2 Cedar Ave #84  departamento
# NaN           9      27    Ezekiel      Chui   2 Cedar Ave #84  departamento
#
#      business_type bedrooms bathrooms parking_lots  ... localidad    city  \
# NaN  Rental & Sale        3         2            1  ...      Suba  Bogotá
# NaN         Rental        3         1            0  ...      Suba  Bogotá
# NaN         Rental        3         1            0  ...      Suba  Bogotá
# NaN         Rental        3         1            0  ...      Suba  Bogotá
# NaN         Rental        3         1            0  ...      Suba  Bogotá
#
#                      region   country scheduled_id                 begin_date  \
# NaN  Región De Cundinamarca  Colombia       164788  2022-01-03T10:00:00-03:00
# NaN  Región De Cundinamarca  Colombia       166464  2022-01-07T11:00:00-03:00
# NaN  Región De Cundinamarca  Colombia       167371  2022-01-10T13:00:00-03:00
# NaN  Región De Cundinamarca  Colombia       165579  2022-01-03T21:00:00-03:00
# NaN  Región De Cundinamarca  Colombia       164994  2022-01-02T12:00:00-03:00
#
#                       end_date type_visit     status temperature
# NaN  2022-01-03T12:00:00-03:00      Visit  Cancelled        57.8
# NaN  2022-01-07T13:00:00-03:00      Visit  Cancelled        55.2
# NaN  2022-01-10T15:00:00-03:00      Visit  Cancelled        55.9
# NaN  2022-01-03T23:00:00-03:00      Visit  Cancelled        57.6
# NaN  2022-01-02T14:00:00-03:00      Visit  Cancelled        57.7
#
# [5 rows x 25 columns]

# %% [markdown]
# Ahora procedemos a calcular la temperatura promedio:

# %%
print(f'\nNúmero de temperaturas promedio registradas en la localidad de {location}:\n {len(location_visits_with_temp_df)}')
print(f'\nTodas las temperaturas promedio de la localidad de {location}:\n {location_visits_with_temp_df.temperature.to_list()}')
print(f'\nTemperatura global promedio de las visitas hechas en la localidad de {location}:\n {location_visits_with_temp_df.temperature.mean()}')
# Out:
# Número de temperaturas promedio registradas en la localidad de Suba:
#  86
#
# Todas las temperaturas promedio de la localidad de Suba:
#  [57.8, 55.2, 55.9, 57.6, 57.7, 59.3, 56.7, 56.7, 59.3, 56.2, 57.3, 56.2, 57.3, 58.6, 58.6, 57.7, 57.7, 57.7, 55.9, 55.9, 57.3, 57.3, 55.1, 58.0, 59.5, 59.6, 59.6, 59.6, 59.5, 59.5, 55.5, 57.2, 59.0, 57.2, 55.5, 55.8, 55.8, 55.3, 59.6, 59.5, 59.5, 56.0, 58.7, 58.7, 59.3, 59.5, 56.5, 55.4, 59.3, 55.6, 58.8, 58.8, 59.0, 59.0, 57.4, 57.4, 57.6, 57.2, 57.8, 55.35, 57.4, 55.8, 55.8, 55.6, 59.1, 59.1, 56.4, 57.7, 57.2, 55.2, 55.7, 57.4, 57.4, 57.4, 57.4, 59.2, 59.3, 59.3, 57.6, 59.5, 59.5, 56.9, 57.9, 58.6, 56.9, 56.9]
#
# Temperatura global promedio de las visitas hechas en la localidad de Suba:
#  57.60174418604649

# %% [markdown]
# **RESPUESTA:**
#
# Temperatura promedio para las visitas realizadas en la localidad de Suba: 57.60174418604649

# %% [markdown]
# **CONCLUSIÓN:**
#
# Fue un excelente reto técnico. La mayor parte del esfuerzo se enfoco en el entendimiento de la API y la extracción de datos de la misma. Así mismo, una limitante importante fue el umbral máximo permitido de "requests" que se podían hacer a la misma por día. Debido a esto, se observan varias mejoras de optimización que se podrían hacer en el futuro:
#
# <ul>
#   <li>Se pudo haber hecho la extracción de datos de la API para todas las visitas, en lugar de repetir la extracción en cada pregunta. Evidentemente, debido a que es un desafío técnico se repitió la lógica para reiterar el procedimiento de extracción, transformación y carga en cada pregunta</li>
#   <li>Hubo una gran repetiión de código, lo que significa que se pudo haber encapsulado aún más la lógica en nuevas funciones.</li>
# </ul>
#
# Finalmente, solo me queda decir que me siento muy emocionado de poder trabajar en Houm y colaborar con un gran equipo de datos para lograr que la empresa crezca tecnológicamente y se convierta en un referente mundial en la venta y renta de propiedades.
#
# Espero poder formar parte de la familia de Houm.
